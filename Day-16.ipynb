# %% [markdown]
# ## We have shared a dataset on which you will have to perform Data analysis with pandas, matplotlib and seaborn. And please make sure create all charts that we have teach in our previous class. And code should be with well commented. And Mention your theoretical observation in comment what you will observed by the charts. And try with different columns and different charts.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("StudentsPerformance.csv") #load the data
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head() #First 5
# df.tail() Last 5
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.relplot(x='reading score',y='writing score',data=df,hue='gender') #Scatter plot-->relation b/w reading and writing scote and differentiating b/w male nd female

# %%
sns.relplot(x='reading score',y='writing score',data=df,hue='gender',kind='line')  # changed pattern of scatter plot(kind=line)

# %%
sns.catplot(x='race/ethnicity',y='math score',data=df,kind='bar')

# %%
sns.catplot(x='race/ethnicity',y='math score',data=df,kind='violin')
plt.title('JECRC') #gives title
plt.xlabel("Group")
plt.ylabel("Math score")
# kind--> violin, strip, bar, swarn
# Out:
# Text(30.570061728395068, 0.5, 'Math score')

# %%
sns.catplot(x='race/ethnicity',y='math score',data=df,kind='strip',hue='gender',col='gender' ) # differentiating math score of diff groups and agin seperating them on the basis of their gender
plt.show() # removes unnecasry values

# %%
label = list(df['parental level of education'].value_counts().keys())
label
# Out:
# ['some college',
#  "associate's degree",
#  'high school',
#  'some high school',
#  "bachelor's degree",
#  "master's degree"]

# %%
val = list(df['parental level of education'].value_counts().values)
val
# Out:
# [226, 222, 196, 179, 118, 59]

# %%
ls = [0.2,0,0,0,0,0] # makes that particular content at gap 
plt.pie(val,labels=label,wedgeprops={'ec':'k'},explode=ls,autopct="%1.2f%%",shadow=True) #edgecolor
plt.title('Parental level of education')
plt.show()
